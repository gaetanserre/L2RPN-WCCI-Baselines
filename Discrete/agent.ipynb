# %%
from gym import Env, spaces
from grid2op import make
from grid2op.Parameters import Parameters
from lightsim2grid import LightSimBackend
from stable_baselines3 import DQN

import numpy as np

# %%
p = Parameters()
p.LIMIT_INFEASIBLE_CURTAILMENT_STORAGE_ACTION = True

# %%
class grid2opGymEnv(Env):
  def __init__(self, env_name):
    super(grid2opGymEnv, self).__init__()

    self.env = make(env_name,
                    backend=LightSimBackend(),
                    param=p)

    self.observation_space = spaces.Box(low=-np.inf,
                                        high=np.inf,
                                        shape=(3868,),
                                        dtype=np.float32)
    self.action_space = spaces.Discrete(1000)

    actions = np.load("top1000_actions.npz", allow_pickle=True)["actions"]
    self.all_actions = []
    for action in actions:
      self.all_actions.append(self.env.action_space.from_vect(action))
      
  def reset(self):
    obs = self.env.reset()
    return obs.to_vect()
  
  def step(self, action):
    action = self.all_actions[action]
    obs, reward, done, info = self.env.step(action)
    return obs.to_vect(), reward, done, info

# %%
env = grid2opGymEnv("l2rpn_neurips_2020_track2_small")

# %%
model = DQN("MlpPolicy", env, verbose=1, buffer_size=50_000, learning_starts=1000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=10000, log_interval=4)
# Out:
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.99e+03 |
# |    exploration_rate | 0.958    |
# | time/               |          |
# |    episodes         | 4        |
# |    fps              | 6        |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 44       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.5     |
# |    ep_rew_mean      | 8.79e+03 |
# |    exploration_rate | 0.913    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 7        |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 92       |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.14e+03 |
# |    exploration_rate | 0.877    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7        |
# |    time_elapsed     | 17       |
# |    total_timesteps  | 129      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.8     |
# |    ep_rew_mean      | 8.02e+03 |
# |    exploration_rate | 0.836    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 7        |
# |    time_elapsed     | 22       |
# |    total_timesteps  | 173      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.3     |
# |    ep_rew_mean      | 7.75e+03 |
# |    exploration_rate | 0.803    |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 7        |
# |    time_elapsed     | 27       |
# |    total_timesteps  | 207      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 7.87e+03 |
# |    exploration_rate | 0.762    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 7        |
# |    time_elapsed     | 33       |
# |    total_timesteps  | 250      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 9.93     |
# |    ep_rew_mean      | 7.52e+03 |
# |    exploration_rate | 0.736    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 7        |
# |    time_elapsed     | 38       |
# |    total_timesteps  | 278      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 7.91e+03 |
# |    exploration_rate | 0.688    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 7        |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 328      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 7.89e+03 |
# |    exploration_rate | 0.644    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 7        |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 375      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 7.9e+03  |
# |    exploration_rate | 0.606    |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 7        |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 415      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.2     |
# |    ep_rew_mean      | 7.8e+03  |
# |    exploration_rate | 0.574    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 7        |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 448      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.11e+03 |
# |    exploration_rate | 0.516    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 7        |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 509      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.4     |
# |    ep_rew_mean      | 7.91e+03 |
# |    exploration_rate | 0.485    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 7        |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 542      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.6     |
# |    ep_rew_mean      | 8.11e+03 |
# |    exploration_rate | 0.437    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 7        |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 593      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.7     |
# |    ep_rew_mean      | 8.08e+03 |
# |    exploration_rate | 0.393    |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 7        |
# |    time_elapsed     | 80       |
# |    total_timesteps  | 639      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 10.9     |
# |    ep_rew_mean      | 8.21e+03 |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 8        |
# |    time_elapsed     | 86       |
# |    total_timesteps  | 700      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.27e+03 |
# |    exploration_rate | 0.286    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 8        |
# |    time_elapsed     | 91       |
# |    total_timesteps  | 752      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.34e+03 |
# |    exploration_rate | 0.238    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 8        |
# |    time_elapsed     | 96       |
# |    total_timesteps  | 802      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.29e+03 |
# |    exploration_rate | 0.199    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 8        |
# |    time_elapsed     | 102      |
# |    total_timesteps  | 843      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11       |
# |    ep_rew_mean      | 8.2e+03  |
# |    exploration_rate | 0.166    |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 8        |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 878      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.3     |
# |    ep_rew_mean      | 8.41e+03 |
# |    exploration_rate | 0.0985   |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 8        |
# |    time_elapsed     | 112      |
# |    total_timesteps  | 949      |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 11.1     |
# |    ep_rew_mean      | 8.22e+03 |
# |    exploration_rate | 0.07     |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 8        |
# |    time_elapsed     | 117      |
# |    total_timesteps  | 979      |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/gaetanserre/Documents/Projects/L2RPN-WCCI-Baselines/Discrete/agent.ipynb Cell 5' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/gaetanserre/Documents/Projects/L2RPN-WCCI-Baselines/Discrete/agent.ipynb#ch0000009?line=0'>1</a> model.learn(total_timesteps=10000, log_interval=4)
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py:258, in DQN.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=244'>245</a> def learn(
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=245'>246</a>     self,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=246'>247</a>     total_timesteps: int,
#    (...)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=254'>255</a>     reset_num_timesteps: bool = True,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=255'>256</a> ) -> OffPolicyAlgorithm:
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=257'>258</a>     return super(DQN, self).learn(
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=258'>259</a>         total_timesteps=total_timesteps,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=259'>260</a>         callback=callback,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=260'>261</a>         log_interval=log_interval,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=261'>262</a>         eval_env=eval_env,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=262'>263</a>         eval_freq=eval_freq,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=263'>264</a>         n_eval_episodes=n_eval_episodes,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=264'>265</a>         tb_log_name=tb_log_name,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=265'>266</a>         eval_log_path=eval_log_path,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=266'>267</a>         reset_num_timesteps=reset_num_timesteps,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/dqn/dqn.py?line=267'>268</a>     )
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:347, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=343'>344</a> callback.on_training_start(locals(), globals())
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=345'>346</a> while self.num_timesteps < total_timesteps:
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=346'>347</a>     rollout = self.collect_rollouts(
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=347'>348</a>         self.env,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=348'>349</a>         train_freq=self.train_freq,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=349'>350</a>         action_noise=self.action_noise,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=350'>351</a>         callback=callback,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=351'>352</a>         learning_starts=self.learning_starts,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=352'>353</a>         replay_buffer=self.replay_buffer,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=353'>354</a>         log_interval=log_interval,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=354'>355</a>     )
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=356'>357</a>     if rollout.continue_training is False:
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=357'>358</a>         break
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py:580, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=576'>577</a> actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=578'>579</a> # Rescale and perform action
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=579'>580</a> new_obs, rewards, dones, infos = env.step(actions)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=581'>582</a> self.num_timesteps += env.num_envs
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/off_policy_algorithm.py?line=582'>583</a> num_collected_steps += 1
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:162, in VecEnv.step(self, actions)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=154'>155</a> """
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=155'>156</a> Step the environments with the given action
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=156'>157</a>
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=157'>158</a> :param actions: the action
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=158'>159</a> :return: observation, reward, done, information
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=159'>160</a> """
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=160'>161</a> self.step_async(actions)
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/base_vec_env.py?line=161'>162</a> return self.step_wait()
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:49, in DummyVecEnv.step_wait(self)
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=45'>46</a>     if self.buf_dones[env_idx]:
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=46'>47</a>         # save final observation where user can get it, then reset
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=47'>48</a>         self.buf_infos[env_idx]["terminal_observation"] = obs
# ---> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=48'>49</a>         obs = self.envs[env_idx].reset()
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=49'>50</a>     self._save_obs(env_idx, obs)
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py?line=50'>51</a> return (self._obs_from_buf(), np.copy(self.buf_rews), np.copy(self.buf_dones), deepcopy(self.buf_infos))
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/monitor.py:79, in Monitor.reset(self, **kwargs)
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/monitor.py?line=76'>77</a>         raise ValueError(f"Expected you to pass keyword argument {key} into reset")
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/monitor.py?line=77'>78</a>     self.current_reset_info[key] = value
# ---> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/stable_baselines3/common/monitor.py?line=78'>79</a> return self.env.reset(**kwargs)
#
# /Users/gaetanserre/Documents/Projects/L2RPN-WCCI-Baselines/Discrete/agent.ipynb Cell 2' in grid2opGymEnv.reset(self)
#      <a href='vscode-notebook-cell:/Users/gaetanserre/Documents/Projects/L2RPN-WCCI-Baselines/Discrete/agent.ipynb#ch0000007?line=17'>18</a> def reset(self):
# ---> <a href='vscode-notebook-cell:/Users/gaetanserre/Documents/Projects/L2RPN-WCCI-Baselines/Discrete/agent.ipynb#ch0000007?line=18'>19</a>   obs = self.env.reset()
#      <a href='vscode-notebook-cell:/Users/gaetanserre/Documents/Projects/L2RPN-WCCI-Baselines/Discrete/agent.ipynb#ch0000007?line=19'>20</a>   return obs.to_vect()
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/MultiMixEnv.py:354, in MultiMixEnvironment.reset(self, random)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/MultiMixEnv.py?line=350'>351</a>     self.env_index = (self.env_index + 1) % len(self.mix_envs)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/MultiMixEnv.py?line=352'>353</a> self.current_env = self.mix_envs[self.env_index]
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/MultiMixEnv.py?line=353'>354</a> self.current_env.reset()
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/MultiMixEnv.py?line=354'>355</a> return self.get_obs()
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py:866, in Environment.reset(self)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=863'>864</a> super().reset()
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=864'>865</a> self.chronics_handler.next_chronics()
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=865'>866</a> self.chronics_handler.initialize(
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=866'>867</a>     self.backend.name_load,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=867'>868</a>     self.backend.name_gen,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=868'>869</a>     self.backend.name_line,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=869'>870</a>     self.backend.name_sub,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=870'>871</a>     names_chronics_to_backend=self._names_chronics_to_backend,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=871'>872</a> )
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=872'>873</a> self._env_modification = None
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Environment/Environment.py?line=873'>874</a> self._reset_maintenance()
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py:319, in Multifolder.initialize(self, order_backend_loads, order_backend_prods, order_backend_lines, order_backend_subs, names_chronics_to_backend)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=315'>316</a>     seed_chronics = self.space_prng.randint(max_int)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=316'>317</a>     self.data.seed(seed_chronics)
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=318'>319</a> self.data.initialize(
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=319'>320</a>     order_backend_loads,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=320'>321</a>     order_backend_prods,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=321'>322</a>     order_backend_lines,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=322'>323</a>     order_backend_subs,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=323'>324</a>     names_chronics_to_backend=names_chronics_to_backend,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/multiFolder.py?line=324'>325</a> )
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFileWithForecasts.py:136, in GridStateFromFileWithForecasts.initialize(self, order_backend_loads, order_backend_prods, order_backend_lines, order_backend_subs, names_chronics_to_backend)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFileWithForecasts.py?line=133'>134</a> load_p_iter = self._get_data("load_p_forecasted")
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFileWithForecasts.py?line=134'>135</a> load_q_iter = self._get_data("load_q_forecasted")
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFileWithForecasts.py?line=135'>136</a> prod_p_iter = self._get_data("prod_p_forecasted")
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFileWithForecasts.py?line=136'>137</a> prod_v_iter = self._get_data("prod_v_forecasted")
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFileWithForecasts.py?line=137'>138</a> hazards = None  # no hazards in forecast
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py:293, in GridStateFromFile._get_data(self, data_name)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=290'>291</a>     nrows = self.max_iter + 1
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=291'>292</a> if file_ext is not None:
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=292'>293</a>     res = pd.read_csv(
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=293'>294</a>         os.path.join(self.path, "{}{}".format(data_name, file_ext)),
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=294'>295</a>         sep=self.sep,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=295'>296</a>         chunksize=self.chunk_size,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=296'>297</a>         nrows=nrows,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=297'>298</a>     )
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=298'>299</a> else:
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/grid2op/Chronics/gridStateFromFile.py?line=299'>300</a>     res = None
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=571'>572</a> _validate_names(kwds.get("names", None))
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=573'>574</a> # Create the parser.
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=574'>575</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=576'>577</a> if chunksize or iterator:
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=929'>930</a>     self.options["has_index_names"] = kwds["has_index_names"]
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=931'>932</a> self.handles: IOHandles | None = None
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=932'>933</a> self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1231, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1227'>1228</a>     f = self.handles.handle
#    <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1229'>1230</a> try:
# -> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1230'>1231</a>     return mapping[engine](f, **self.options)
#    <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1231'>1232</a> except Exception:
#    <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1232'>1233</a>     if self.handles is not None:
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py:75, in CParserWrapper.__init__(self, src, **kwds)
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=71'>72</a>     kwds.pop(key, None)
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=73'>74</a> kwds["dtype"] = ensure_dtype_objs(kwds.get("dtype", None))
# ---> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=74'>75</a> self._reader = parsers.TextReader(src, **kwds)
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=76'>77</a> self.unnamed_cols = self._reader.unnamed_cols
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/io/parsers/c_parser_wrapper.py?line=78'>79</a> # error: Cannot determine type of 'names'
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:544, in pandas._libs.parsers.TextReader.__cinit__()
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:633, in pandas._libs.parsers.TextReader._get_header()
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:847, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/site-packages/pandas/_libs/parsers.pyx:1952, in pandas._libs.parsers.raise_parser_error()
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/bz2.py:184, in BZ2File.read1(self, size)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/bz2.py?line=181'>182</a> if size < 0:
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/bz2.py?line=182'>183</a>     size = io.DEFAULT_BUFFER_SIZE
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/bz2.py?line=183'>184</a> return self._buffer.read1(size)
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/_compression.py:68, in DecompressReader.readinto(self, b)
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=65'>66</a> def readinto(self, b):
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=66'>67</a>     with memoryview(b) as view, view.cast("B") as byte_view:
# ---> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=67'>68</a>         data = self.read(len(byte_view))
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=68'>69</a>         byte_view[:len(data)] = data
#      <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=69'>70</a>     return len(data)
#
# File ~/miniconda3/envs/L2RPN/lib/python3.9/_compression.py:103, in DecompressReader.read(self, size)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=100'>101</a>     else:
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=101'>102</a>         rawblock = b""
# --> <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=102'>103</a>     data = self._decompressor.decompress(rawblock, size)
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=103'>104</a> if data:
#     <a href='file:///Users/gaetanserre/miniconda3/envs/L2RPN/lib/python3.9/_compression.py?line=104'>105</a>     break
#
# KeyboardInterrupt:
